# %% [markdown]
# <a href="https://colab.research.google.com/github/Ian88888888/2024fin_data/blob/main/%E3%80%8Cfred_example_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fredapi

# %%
from fredapi import Fred

# %%
fred = Fred(api_key='7c28f3ff791ca10cf55111df923f7ff3')

# %%
data1 = fred.get_series('MICH')

# %%
data1 = fred.get_series('MICH', '6/1/2021')

# %%
data1.plot()
# Out:
# <Axes: >

# %%
data2 = fred.get_series('UNRATE')

# %%
data2 = fred.get_series('UNRATE', '6/1/2021')

# %%
data1.plot()
data2.plot()
# Out:
# <Axes: >

# %%
df1 = data1.to_frame(name="MICH")
df2 = data2.to_frame(name='UNRATE')

# %%
import pandas as pd
df_merged = pd.concat([df1, df2], axis=1)

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot(df_merged.index, df_merged['MICH'])
plt.plot(df_merged.index, df_merged['UNRATE'])

# %%
fig,ax = plt.subplots()
ax.plot(df_merged.index, df_merged['MICH'],color="blue",marker="o")
ax2=ax.twinx()
ax2.plot(df_merged.index, df_merged['UNRATE'],color="red")
fig.savefig('折線圖.jpg',format='jpeg')

# %%
df_merged.corr()
# Out:
#             MICH    UNRATE
# MICH    1.000000 -0.055352
# UNRATE -0.055352  1.000000

# %%
import seaborn as sns
sns.heatmap(df_merged.corr())
# Out:
# <Axes: >

# %%
svm = sns.heatmap(df_merged.corr(), cmap="Blues", annot=True)
figure = svm.get_figure()
figure.savefig('相關係數.png', dpi=400)
