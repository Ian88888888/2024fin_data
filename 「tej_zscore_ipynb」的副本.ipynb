# %% [markdown]
# <a href="https://colab.research.google.com/github/Ian88888888/2024fin_data/blob/main/%E3%80%8Ctej_zscore_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/Ian88888888/2024fin_data/refs/heads/main/balance(1).csv"

# %%
df1 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df1
# Out:
#                   YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 2412 CHT          45261.0      4.0             Y   12.0      NTD
# 4904 Far EasTone  45261.0      4.0             Y   12.0      NTD
#
#                   Total cash and cash equivalents  \
# CO_ID
# 2412 CHT                               33823884.0
# 4904 Far EasTone                        4392483.0
#
#                   Total current financial assets at fair value through profit or loss  \
# CO_ID
# 2412 CHT                                                      904.0
# 4904 Far EasTone                                           712578.0
#
#                   Financial assets at fair value through other comprehensive income - Current  \
# CO_ID
# 2412 CHT                                                        0.0
# 4904 Far EasTone                                                0.0
#
#                   Financial assets measured at amortized cost - Current  \
# CO_ID
# ...

# %%
url = "https://raw.githubusercontent.com/Ian88888888/2024fin_data/refs/heads/main/income.csv"

# %%
df2 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df2
# Out:
#                   YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 2412 CHT          45261.0      4.0             Y   12.0      NTD
# 4904 Far EasTone  45261.0      4.0             Y   12.0      NTD
#
#                   Gross operating revenue  Total rental revenue  \
# CO_ID
# 2412 CHT                      222079193.0             1120067.0
# 4904 Far EasTone               93690417.0                   0.0
#
#                   Operating revenue - Disposal of lands  Interest revenue  \
# CO_ID
# 2412 CHT                                            0.0               0.0
# 4904 Far EasTone                                    0.0               0.0
#
#                   Operating revenue - disposal of investments  ...  \
# CO_ID                                                          ...
# 2412 CHT                                                  0.0  ...
# 4904 Far EasTone                                          0.0  ...
#
# ...

# %%
df1.columns
# Out:
# Index(['YYYY/MM', 'Quarter', 'consolidation', 'Month', 'Currency',
#        'Total cash and cash equivalents',
#        'Total current financial assets at fair value through profit or loss',
#        'Financial assets at fair value through other comprehensive income - Current',
#        'Financial assets measured at amortized cost - Current',
#        'Current financial assets for hedging',
#        ...
#        'Other equity - unearned compensation', 'Other equity, others',
#        'Total other equity interest', 'Treasury shares',
#        'Total equity attributable to owners of parent',
#        'Interests in the former associate or jointly controlled entity',
#        'Non-controlling interest in pre-acquisition share capital',
#        'Non-controlling interests', 'Total equity',
#        'Total liabilities & equity'],
#       dtype='object', length=111)

# %%
df1.index
# Out:
# Index(['2412 CHT', '4904 Far EasTone'], dtype='object', name='CO_ID')

# %%
A_1101 = (df1.loc['2412 CHT','Total current assets'] - df1.loc['2412 CHT','Total current liabilities'])/df1.loc['2412 CHT','Total assets']

# %%
A_1101
# Out:
# 0.07145931748698549

# %%
X1 ='Total current assets'
X2 ='Total current liabilities'
X3 ='Total assets'
X4 ='Total retained earnings'
X5 ='Earnings before interest and tax'
X6 ='Total equity'
X7 ='Total liabilities'
X8 ='Total operating revenue'
CHT ='2412 CHT'
Far ='4904 Far EasTone'

# %%
A_CHT = (df1.loc[CHT,X1] - df1.loc[CHT,X2])/df1.loc[CHT, X3]

# %%
B_CHT = df1.loc[CHT,X4]/df1.loc[CHT, X3]

# %%
C_CHT = df2.loc[CHT,X5]/df1.loc[CHT, X3]

# %%
D_CHT = df1.loc[CHT,X6]/df1.loc[CHT, X7] #調整分子項定義，採用股東權益帳面價值

# %%
E_CHT = df2.loc[CHT,X8]/df1.loc[CHT, X3]

# %%
Z_score_CHT = 1.2*A_CHT + 1.4*B_CHT + 3.3*C_CHT+ 0.6*D_CHT +1.0*E_CHT

# %%
Z_score_CHT, A_CHT, B_CHT, C_CHT, D_CHT, E_CHT
# Out:
# (3.001638528055747,
#  0.07145931748698549,
#  0.25402106569190813,
#  0.09030015476923446,
#  3.060442153780204,
#  0.42600205209609726)

# %%
A_Far = (df1.loc[Far,X1] - df1.loc[Far,X2])/df1.loc[Far, X3]

# %%
B_Far = df1.loc[Far,X4]/df1.loc[Far, X3]

# %%
C_Far = df2.loc[Far,X5]/df1.loc[Far, X3]

# %%
D_Far = df1.loc[Far,X6]/df1.loc[Far, X7]

# %%
E_Far = df2.loc[Far,X8]/df1.loc[Far, X3]

# %%
Z_score_Far = 1.2*A_Far + 1.4*B_Far + 3.3*C_Far + 0.6*D_Far +1.0*E_Far

# %%
Z_score_Far, A_Far, B_Far, C_Far, D_Far, E_Far
# Out:
# (1.8246460738677195,
#  0.11716660516627467,
#  0.3501663370468784,
#  0.046651515771161355,
#  1.3244457926274817,
#  0.2451957981812386)
